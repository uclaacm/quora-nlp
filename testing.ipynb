# %%
from sentence_transformers import SentenceTransformer
x = "lmao"
BERT = SentenceTransformer("bert-base-nli-mean-tokens")
BERT.encode(x)
# Out:
# array([-2.91810900e-01, -4.31750119e-01,  1.74075890e+00, -1.41180560e-01,
#         7.66268671e-01,  6.70530021e-01, -9.09422278e-01,  6.17036700e-01,
#         1.41829967e-01, -3.46300066e-01, -5.38350940e-01,  7.88877010e-01,
#         2.78302282e-01,  5.10535061e-01,  1.13567519e+00,  3.33949506e-01,
#        -7.48116136e-01, -1.85164418e-02,  8.77129473e-03, -7.92817414e-01,
#         2.31893450e-01,  5.39416730e-01,  1.24502899e-02, -4.02298510e-01,
#        -1.71433851e-01, -7.20302224e-01,  1.99416667e-01, -1.65634131e+00,
#        -2.12493926e-01, -8.74104872e-02, -1.07591972e-01, -4.46961105e-01,
#         3.92710507e-01, -1.17486253e-01,  2.63134032e-01,  1.85354978e-01,
#        -6.39166951e-01,  4.05467331e-01, -7.57355019e-02, -1.54153658e-02,
#         1.43530262e+00, -1.38035133e-01,  3.73007476e-01,  5.01057982e-01,
#        -7.32459366e-01, -2.91178882e-01, -5.57978630e-01, -3.53894651e-01,
# ...

# %%
import pandas as pd
import numpy as np
import torch

# %%
df = pd.DataFrame([['wqfwegf',2,3],['afqeqwg',1,1]], columns=  ['a', 'b', 'c'])

# %%
torch.Tensor((df.iloc[:,0]).to_list())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\email\OneDrive\Documents\Python\quora-nlp\testing.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/email/OneDrive/Documents/Python/quora-nlp/testing.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> torch.Tensor((df.iloc[:,0]).to_list())
#
# TypeError: must be real number, not str

# %%
torch.tensor(df.a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\email\OneDrive\Documents\Python\quora-nlp\testing.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/email/OneDrive/Documents/Python/quora-nlp/testing.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> torch.tensor(df.a)
#
# ValueError: too many dimensions 'str'

# %%
BERT.encode(df.a)
# Out:
# array([[ 0.47799674, -0.23350158,  1.9571972 , ...,  0.2066038 ,
#          0.05237172, -0.28858528],
#        [ 0.3361875 ,  0.0798404 ,  2.0466855 , ..., -0.46091795,
#          0.07574051,  0.32593852]], dtype=float32)
